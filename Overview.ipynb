# %% [markdown]
# # TensorFlow overview
# ## Agenda:
#
#
# 1.   What is TensorFlow?
# 2.   Who uses it and on what problems?
# 3.   What are its drawbacks?
# 4.   Where does Deep learning fit into AI, Machine learning?
# 5.   What are the APIs (using Keras as example)?
#
#
#
# ---
#
# ## TensorFlow
# TensorFlow™ is an open source software library for numerical computation
# - TensorFlow uses data flow graphs thus maping input to output
#
# Originally created by researchers at Google as a single infrastructure for machine learning in both production and research
#
# Open sourced under the Apache 2.0 License in November 2015
#
# Growing quickly - used by big companies such as Google, OpenAI, NVIDIA, Intel, SAP, eBay, Airbus, Uber, Airbnb, Snap, Dropbox and startups alike
#
#
# ## Applications
#
# Restores the color of old black & white photos
#
# Google Translate "reads" the text and replaces it with a text in English in real-time
#
# Image style transfer
#
# Generating new photos
#
# Generate music
#
# Self driving cars
#
# Healthcare
#
# **What are you hoping Tensorflow will do for you**
#
# ## Potential Drawbacks
#
#
# *   Steep learning curve
# *   Need a lot of data
#
# ## Deep Learning within AI, ML
#
# **Artificial Intelligence:**
#
# Mimicking the human brain to train machines performing human tasks
#
# **Machine Learning:**
#
# A branch of AI that teaches the machine how to learn
#
# **Deep Learning:**
#
# A class of machine learning algorithms that uses multiple cascade processing stages - each stage learns a representation of the data
#
# ## Machine Learning Pipeline
#
#
# ## APIs
#
# Out of many the most popular APIs include
# * Keras
# * TFLearn
# * Sonnet
#
# These high-level APIs allow for faster experimentation -- you can call a complex neural network models in a few lines of code
#
# The APIs have attracted a sizeable number of users
#
# However, the primary purpose of TensorFlow is not to provide out-of-the-box machine learning solutions.
#
# Instead, TensorFlow provides an extensive suite of functions and classes that allow users to define models from scratch.
#
# This is more complicated, but offers much more flexibility. You can build almost any architecture you can think of in TensorFlow.
